# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('../')
import cv2 as cv
from PIL import Image, ImageDraw
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
from src.utils.graphs import get_keypoints, relative_neighborhood, random_graph, delaunay_triangulation, delete_not_RNG_edges
from src.utils.visualize import draw_graph
import networkx as nx
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rG = random_graph(100,0)
arr = draw_graph(rG,radius=1)
keys = []
for idx, node in enumerate(rG._node):
    x = rG._node[idx]['x']
    y = rG._node[idx]['y']
    keys.append([x,y])

# %%
g = relative_neighborhood(keys)
arr_1 = draw_graph(g)
len(g.edges)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 4950/4950 [00:00<00:00, 11358.95it/s]
# 119

# %%
from scipy.spatial import Delaunay

# %%
len(keys)
# Out:
# 100

# %%
g = delaunay_triangulation(keys)

# %%
arr = draw_graph(g)

# %%
g_r= delete_not_RNG_edges(g)

# %%
arr_2 = draw_graph(g_r)

# %%
np.array_equal(arr_1,arr_2)
# Out:
# True
